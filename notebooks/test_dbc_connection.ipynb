# %%
print("Hello! Let's learn about Databricks Declarative Automation Bundles.")
# Out:
# Hello! Let's learn about Databricks Declarative Automation Bundles.

# %%
spark.sql("SHOW CATALOGS").show()
# Out:
# +-------------+
# |      catalog|
# +-------------+
# | citibike_dev|
# |citibike_prod|
# |citibike_test|
# |  nyctaxi_dev|
# |          raw|
# |      samples|
# |       system|
# |    workspace|
# +-------------+

# %%
spark.sql("""
    USE SCHEMA sql_challenges
""")
spark.sql("""
    SHOW TABLES
""")
# Out:
# DataFrame[database: string, tableName: string, isTemporary: boolean]

# %%
# %sql
use schema sql_challenges;
show tables
# Out:
# DataFrame[database: string, tableName: string, isTemporary: boolean]

# %%
fs ls /
# Out:
# ---------------------------------------------------------------------------
# PermissionDenied                          Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_ipython().run_line_magic('fs', 'ls /')
#
# File ~\.ipython\profile_default\startup\00-databricks-init-4345b90cdbba7425a7042b5998d089f5.py:158, in DatabricksMagics.fs(self, line, local_ns)
#     149     raise NameError(
#     150         cmd_str
#     151         + " is not a valid command for %fs. Valid commands are "
#    (...)    155         )
#     156     )
#     157 cmd = dbutils.fs.__getattribute__(cmd_str)
# --> 158 return cmd(*args[1:])
#
# File d:\Learning & Development\Databricks\Declarative Automation Bundles\Course CI-CD with DAB\dab_project\.venv\Lib\site-packages\databricks\sdk\dbutils.py:60, in _FsUtil.ls(self, dir)
#      58 def ls(self, dir: str) -> List[FileInfo]:
#      59     """Lists the contents of a directory"""
# ---> 60     return [
#      61         FileInfo(
# ...
